# %%
# !pip install skillsnetwork==0.19.2
# Out:
# Collecting skillsnetwork==0.19.2
#   Downloading skillsnetwork-0.19.2-py3-none-any.whl (12 kB)
# Requirement already satisfied: requests<3,>=2 in c:\users\luis\anaconda3\lib\site-packages (from skillsnetwork==0.19.2) (2.28.1)
# Requirement already satisfied: tqdm<5,>=4 in c:\users\luis\anaconda3\lib\site-packages (from skillsnetwork==0.19.2) (4.64.1)
# Requirement already satisfied: ipywidgets<8,>=7 in c:\users\luis\anaconda3\lib\site-packages (from skillsnetwork==0.19.2) (7.6.5)
# Requirement already satisfied: ipython in c:\users\luis\appdata\roaming\python\python310\site-packages (from skillsnetwork==0.19.2) (8.13.2)
# Requirement already satisfied: jupyterlab-widgets>=1.0.0 in c:\users\luis\anaconda3\lib\site-packages (from ipywidgets<8,>=7->skillsnetwork==0.19.2) (1.0.0)
# Requirement already satisfied: traitlets>=4.3.1 in c:\users\luis\appdata\roaming\python\python310\site-packages (from ipywidgets<8,>=7->skillsnetwork==0.19.2) (5.9.0)
# Requirement already satisfied: nbformat>=4.2.0 in c:\users\luis\anaconda3\lib\site-packages (from ipywidgets<8,>=7->skillsnetwork==0.19.2) (5.7.0)
# Requirement already satisfied: ipykernel>=4.5.1 in c:\users\luis\appdata\roaming\python\python310\site-packages (from ipywidgets<8,>=7->skillsnetwork==0.19.2) (6.22.0)
# Requirement already satisfied: widgetsnbextension~=3.5.0 in c:\users\luis\anaconda3\lib\site-packages (from ipywidgets<8,>=7->skillsnetwork==0.19.2) (3.5.2)
# Requirement already satisfied: ipython-genutils~=0.2.0 in c:\users\luis\anaconda3\lib\site-packages (from ipywidgets<8,>=7->skillsnetwork==0.19.2) (0.2.0)
# Requirement already satisfied: decorator in c:\users\luis\anaconda3\lib\site-packages (from ipython->skillsnetwork==0.19.2) (5.1.1)
# Requirement already satisfied: jedi>=0.16 in c:\users\luis\appdata\roaming\python\python310\site-packages (from ipython->skillsnetwork==0.19.2) (0.18.2)
# Requirement already satisfied: matplotlib-inline in c:\users\luis\appdata\roaming\python\python310\site-packages (from ipython->skillsnetwork==0.19.2) (0.1.6)
# Requirement already satisfied: pickleshare in c:\users\luis\appdata\roaming\python\python310\site-packages (from ipython->skillsnetwork==0.19.2) (0.7.5)
# Requirement already satisfied: colorama in c:\users\luis\anaconda3\lib\site-packages (from ipython->skillsnetwork==0.19.2) (0.4.6)
# Requirement already satisfied: pygments>=2.4.0 in c:\users\luis\anaconda3\lib\site-packages (from ipython->skillsnetwork==0.19.2) (2.11.2)
# Requirement already satisfied: stack-data in c:\users\luis\appdata\roaming\python\python310\site-packages (from ipython->skillsnetwork==0.19.2) (0.6.2)
# Requirement already satisfied: prompt-toolkit!=3.0.37,<3.1.0,>=3.0.30 in c:\users\luis\appdata\roaming\python\python310\site-packages (from ipython->skillsnetwork==0.19.2) (3.0.38)
# Requirement already satisfied: backcall in c:\users\luis\appdata\roaming\python\python310\site-packages (from ipython->skillsnetwork==0.19.2) (0.2.0)
# Requirement already satisfied: certifi>=2017.4.17 in c:\users\luis\anaconda3\lib\site-packages (from requests<3,>=2->skillsnetwork==0.19.2) (2022.12.7)
# Requirement already satisfied: charset-normalizer<3,>=2 in c:\users\luis\anaconda3\lib\site-packages (from requests<3,>=2->skillsnetwork==0.19.2) (2.0.4)
# Requirement already satisfied: idna<4,>=2.5 in c:\users\luis\anaconda3\lib\site-packages (from requests<3,>=2->skillsnetwork==0.19.2) (3.4)
# Requirement already satisfied: urllib3<1.27,>=1.21.1 in c:\users\luis\anaconda3\lib\site-packages (from requests<3,>=2->skillsnetwork==0.19.2) (1.26.14)
# Requirement already satisfied: debugpy>=1.6.5 in c:\users\luis\appdata\roaming\python\python310\site-packages (from ipykernel>=4.5.1->ipywidgets<8,>=7->skillsnetwork==0.19.2) (1.6.7)
# Requirement already satisfied: jupyter-core!=5.0.*,>=4.12 in c:\users\luis\appdata\roaming\python\python310\site-packages (from ipykernel>=4.5.1->ipywidgets<8,>=7->skillsnetwork==0.19.2) (5.3.0)
# Requirement already satisfied: comm>=0.1.1 in c:\users\luis\appdata\roaming\python\python310\site-packages (from ipykernel>=4.5.1->ipywidgets<8,>=7->skillsnetwork==0.19.2) (0.1.3)
# Requirement already satisfied: packaging in c:\users\luis\anaconda3\lib\site-packages (from ipykernel>=4.5.1->ipywidgets<8,>=7->skillsnetwork==0.19.2) (22.0)
# Requirement already satisfied: psutil in c:\users\luis\appdata\roaming\python\python310\site-packages (from ipykernel>=4.5.1->ipywidgets<8,>=7->skillsnetwork==0.19.2) (5.9.5)
# Requirement already satisfied: tornado>=6.1 in c:\users\luis\anaconda3\lib\site-packages (from ipykernel>=4.5.1->ipywidgets<8,>=7->skillsnetwork==0.19.2) (6.3.2)
# Requirement already satisfied: nest-asyncio in c:\users\luis\appdata\roaming\python\python310\site-packages (from ipykernel>=4.5.1->ipywidgets<8,>=7->skillsnetwork==0.19.2) (1.5.6)
# Requirement already satisfied: jupyter-client>=6.1.12 in c:\users\luis\appdata\roaming\python\python310\site-packages (from ipykernel>=4.5.1->ipywidgets<8,>=7->skillsnetwork==0.19.2) (8.2.0)
# Requirement already satisfied: pyzmq>=20 in c:\users\luis\appdata\roaming\python\python310\site-packages (from ipykernel>=4.5.1->ipywidgets<8,>=7->skillsnetwork==0.19.2) (25.0.2)
# Requirement already satisfied: parso<0.9.0,>=0.8.0 in c:\users\luis\appdata\roaming\python\python310\site-packages (from jedi>=0.16->ipython->skillsnetwork==0.19.2) (0.8.3)
# Requirement already satisfied: jsonschema>=2.6 in c:\users\luis\anaconda3\lib\site-packages (from nbformat>=4.2.0->ipywidgets<8,>=7->skillsnetwork==0.19.2) (4.17.3)
# Requirement already satisfied: fastjsonschema in c:\users\luis\anaconda3\lib\site-packages (from nbformat>=4.2.0->ipywidgets<8,>=7->skillsnetwork==0.19.2) (2.16.2)
# Requirement already satisfied: wcwidth in c:\users\luis\appdata\roaming\python\python310\site-packages (from prompt-toolkit!=3.0.37,<3.1.0,>=3.0.30->ipython->skillsnetwork==0.19.2) (0.2.6)
# Requirement already satisfied: notebook>=4.4.1 in c:\users\luis\anaconda3\lib\site-packages (from widgetsnbextension~=3.5.0->ipywidgets<8,>=7->skillsnetwork==0.19.2) (6.5.2)
# Requirement already satisfied: asttokens>=2.1.0 in c:\users\luis\appdata\roaming\python\python310\site-packages (from stack-data->ipython->skillsnetwork==0.19.2) (2.2.1)
# Requirement already satisfied: pure-eval in c:\users\luis\appdata\roaming\python\python310\site-packages (from stack-data->ipython->skillsnetwork==0.19.2) (0.2.2)
# Requirement already satisfied: executing>=1.2.0 in c:\users\luis\appdata\roaming\python\python310\site-packages (from stack-data->ipython->skillsnetwork==0.19.2) (1.2.0)
# Requirement already satisfied: six in c:\users\luis\anaconda3\lib\site-packages (from asttokens>=2.1.0->stack-data->ipython->skillsnetwork==0.19.2) (1.16.0)
# Requirement already satisfied: attrs>=17.4.0 in c:\users\luis\anaconda3\lib\site-packages (from jsonschema>=2.6->nbformat>=4.2.0->ipywidgets<8,>=7->skillsnetwork==0.19.2) (22.1.0)
# Requirement already satisfied: pyrsistent!=0.17.0,!=0.17.1,!=0.17.2,>=0.14.0 in c:\users\luis\anaconda3\lib\site-packages (from jsonschema>=2.6->nbformat>=4.2.0->ipywidgets<8,>=7->skillsnetwork==0.19.2) (0.18.0)
# Requirement already satisfied: python-dateutil>=2.8.2 in c:\users\luis\anaconda3\lib\site-packages (from jupyter-client>=6.1.12->ipykernel>=4.5.1->ipywidgets<8,>=7->skillsnetwork==0.19.2) (2.8.2)
# Requirement already satisfied: pywin32>=300 in c:\users\luis\anaconda3\lib\site-packages (from jupyter-core!=5.0.*,>=4.12->ipykernel>=4.5.1->ipywidgets<8,>=7->skillsnetwork==0.19.2) (305.1)
# Requirement already satisfied: platformdirs>=2.5 in c:\users\luis\appdata\roaming\python\python310\site-packages (from jupyter-core!=5.0.*,>=4.12->ipykernel>=4.5.1->ipywidgets<8,>=7->skillsnetwork==0.19.2) (3.5.0)
# Requirement already satisfied: terminado>=0.8.3 in c:\users\luis\anaconda3\lib\site-packages (from notebook>=4.4.1->widgetsnbextension~=3.5.0->ipywidgets<8,>=7->skillsnetwork==0.19.2) (0.17.1)
# Requirement already satisfied: nbconvert>=5 in c:\users\luis\anaconda3\lib\site-packages (from notebook>=4.4.1->widgetsnbextension~=3.5.0->ipywidgets<8,>=7->skillsnetwork==0.19.2) (6.5.4)
# Requirement already satisfied: nbclassic>=0.4.7 in c:\users\luis\anaconda3\lib\site-packages (from notebook>=4.4.1->widgetsnbextension~=3.5.0->ipywidgets<8,>=7->skillsnetwork==0.19.2) (0.5.2)
# Requirement already satisfied: jinja2 in c:\users\luis\anaconda3\lib\site-packages (from notebook>=4.4.1->widgetsnbextension~=3.5.0->ipywidgets<8,>=7->skillsnetwork==0.19.2) (3.1.2)
# Requirement already satisfied: prometheus-client in c:\users\luis\anaconda3\lib\site-packages (from notebook>=4.4.1->widgetsnbextension~=3.5.0->ipywidgets<8,>=7->skillsnetwork==0.19.2) (0.14.1)
# Requirement already satisfied: argon2-cffi in c:\users\luis\anaconda3\lib\site-packages (from notebook>=4.4.1->widgetsnbextension~=3.5.0->ipywidgets<8,>=7->skillsnetwork==0.19.2) (21.3.0)
# Requirement already satisfied: Send2Trash>=1.8.0 in c:\users\luis\anaconda3\lib\site-packages (from notebook>=4.4.1->widgetsnbextension~=3.5.0->ipywidgets<8,>=7->skillsnetwork==0.19.2) (1.8.0)
# Requirement already satisfied: jupyter-server>=1.8 in c:\users\luis\anaconda3\lib\site-packages (from nbclassic>=0.4.7->notebook>=4.4.1->widgetsnbextension~=3.5.0->ipywidgets<8,>=7->skillsnetwork==0.19.2) (1.23.4)
# Requirement already satisfied: notebook-shim>=0.1.0 in c:\users\luis\anaconda3\lib\site-packages (from nbclassic>=0.4.7->notebook>=4.4.1->widgetsnbextension~=3.5.0->ipywidgets<8,>=7->skillsnetwork==0.19.2) (0.2.2)
# Requirement already satisfied: defusedxml in c:\users\luis\anaconda3\lib\site-packages (from nbconvert>=5->notebook>=4.4.1->widgetsnbextension~=3.5.0->ipywidgets<8,>=7->skillsnetwork==0.19.2) (0.7.1)
# Requirement already satisfied: entrypoints>=0.2.2 in c:\users\luis\anaconda3\lib\site-packages (from nbconvert>=5->notebook>=4.4.1->widgetsnbextension~=3.5.0->ipywidgets<8,>=7->skillsnetwork==0.19.2) (0.4)
# Requirement already satisfied: nbclient>=0.5.0 in c:\users\luis\anaconda3\lib\site-packages (from nbconvert>=5->notebook>=4.4.1->widgetsnbextension~=3.5.0->ipywidgets<8,>=7->skillsnetwork==0.19.2) (0.5.13)
# Requirement already satisfied: jupyterlab-pygments in c:\users\luis\anaconda3\lib\site-packages (from nbconvert>=5->notebook>=4.4.1->widgetsnbextension~=3.5.0->ipywidgets<8,>=7->skillsnetwork==0.19.2) (0.1.2)
# Requirement already satisfied: bleach in c:\users\luis\anaconda3\lib\site-packages (from nbconvert>=5->notebook>=4.4.1->widgetsnbextension~=3.5.0->ipywidgets<8,>=7->skillsnetwork==0.19.2) (4.1.0)
# Requirement already satisfied: lxml in c:\users\luis\anaconda3\lib\site-packages (from nbconvert>=5->notebook>=4.4.1->widgetsnbextension~=3.5.0->ipywidgets<8,>=7->skillsnetwork==0.19.2) (4.9.1)
# Requirement already satisfied: tinycss2 in c:\users\luis\anaconda3\lib\site-packages (from nbconvert>=5->notebook>=4.4.1->widgetsnbextension~=3.5.0->ipywidgets<8,>=7->skillsnetwork==0.19.2) (1.2.1)
# Requirement already satisfied: MarkupSafe>=2.0 in c:\users\luis\anaconda3\lib\site-packages (from nbconvert>=5->notebook>=4.4.1->widgetsnbextension~=3.5.0->ipywidgets<8,>=7->skillsnetwork==0.19.2) (2.1.1)
# Requirement already satisfied: mistune<2,>=0.8.1 in c:\users\luis\anaconda3\lib\site-packages (from nbconvert>=5->notebook>=4.4.1->widgetsnbextension~=3.5.0->ipywidgets<8,>=7->skillsnetwork==0.19.2) (0.8.4)
# Requirement already satisfied: beautifulsoup4 in c:\users\luis\anaconda3\lib\site-packages (from nbconvert>=5->notebook>=4.4.1->widgetsnbextension~=3.5.0->ipywidgets<8,>=7->skillsnetwork==0.19.2) (4.11.1)
# Requirement already satisfied: pandocfilters>=1.4.1 in c:\users\luis\anaconda3\lib\site-packages (from nbconvert>=5->notebook>=4.4.1->widgetsnbextension~=3.5.0->ipywidgets<8,>=7->skillsnetwork==0.19.2) (1.5.0)
# Requirement already satisfied: pywinpty>=1.1.0 in c:\users\luis\anaconda3\lib\site-packages (from terminado>=0.8.3->notebook>=4.4.1->widgetsnbextension~=3.5.0->ipywidgets<8,>=7->skillsnetwork==0.19.2) (2.0.10)
# Requirement already satisfied: argon2-cffi-bindings in c:\users\luis\anaconda3\lib\site-packages (from argon2-cffi->notebook>=4.4.1->widgetsnbextension~=3.5.0->ipywidgets<8,>=7->skillsnetwork==0.19.2) (21.2.0)
# Requirement already satisfied: anyio<4,>=3.1.0 in c:\users\luis\anaconda3\lib\site-packages (from jupyter-server>=1.8->nbclassic>=0.4.7->notebook>=4.4.1->widgetsnbextension~=3.5.0->ipywidgets<8,>=7->skillsnetwork==0.19.2) (3.5.0)
# Requirement already satisfied: websocket-client in c:\users\luis\anaconda3\lib\site-packages (from jupyter-server>=1.8->nbclassic>=0.4.7->notebook>=4.4.1->widgetsnbextension~=3.5.0->ipywidgets<8,>=7->skillsnetwork==0.19.2) (0.58.0)
# Requirement already satisfied: cffi>=1.0.1 in c:\users\luis\anaconda3\lib\site-packages (from argon2-cffi-bindings->argon2-cffi->notebook>=4.4.1->widgetsnbextension~=3.5.0->ipywidgets<8,>=7->skillsnetwork==0.19.2) (1.15.1)
# Requirement already satisfied: soupsieve>1.2 in c:\users\luis\anaconda3\lib\site-packages (from beautifulsoup4->nbconvert>=5->notebook>=4.4.1->widgetsnbextension~=3.5.0->ipywidgets<8,>=7->skillsnetwork==0.19.2) (2.3.2.post1)
# Requirement already satisfied: webencodings in c:\users\luis\anaconda3\lib\site-packages (from bleach->nbconvert>=5->notebook>=4.4.1->widgetsnbextension~=3.5.0->ipywidgets<8,>=7->skillsnetwork==0.19.2) (0.5.1)
# Requirement already satisfied: sniffio>=1.1 in c:\users\luis\anaconda3\lib\site-packages (from anyio<4,>=3.1.0->jupyter-server>=1.8->nbclassic>=0.4.7->notebook>=4.4.1->widgetsnbextension~=3.5.0->ipywidgets<8,>=7->skillsnetwork==0.19.2) (1.2.0)
# Requirement already satisfied: pycparser in c:\users\luis\anaconda3\lib\site-packages (from cffi>=1.0.1->argon2-cffi-bindings->argon2-cffi->notebook>=4.4.1->widgetsnbextension~=3.5.0->ipywidgets<8,>=7->skillsnetwork==0.19.2) (2.21)
# Installing collected packages: skillsnetwork
# Successfully installed skillsnetwork-0.19.2

# %%
# !pip install sklearn
# Out:
# Collecting sklearn
#   Downloading sklearn-0.0.post5.tar.gz (3.7 kB)
#   Preparing metadata (setup.py): started
#   Preparing metadata (setup.py): finished with status 'done'
# Building wheels for collected packages: sklearn
#   Building wheel for sklearn (setup.py): started
#   Building wheel for sklearn (setup.py): finished with status 'done'
#   Created wheel for sklearn: filename=sklearn-0.0.post5-py3-none-any.whl size=2970 sha256=b575a6808ee4ae94885013d6c55a433fe802c9f0d0c2ee13cfd4cc393df5cc32
#   Stored in directory: c:\users\luis\appdata\local\pip\cache\wheels\5c\47\e1\386fa7740f1947ad87d16c68041c16ad8c23ca2bfd139a3fe5
# Successfully built sklearn
# Installing collected packages: sklearn
# Successfully installed sklearn-0.0.post5

# %%
# !pip install pyodide-py
# Out:
# Collecting pyodide-py
#   Downloading pyodide_py-0.23.3-py3-none-any.whl (45 kB)
#      -------------------------------------- 45.3/45.3 kB 745.7 kB/s eta 0:00:00
# Installing collected packages: pyodide-py
# Successfully installed pyodide-py-0.23.3

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import warnings
warnings.filterwarnings('ignore')

# %%
import skillsnetwork

# %%
from pyodide.http import pyfetch

# %%
# This function will download the dataset into your browser
async def download(url, filename):
    response = await pyfetch(url)
    if response.status == 200:
        with open(filename, "wb") as f:
            f.write(await response.bytes())

# %%
# you will need to download the dataset; if you are running locally, please comment out the following
await skillsnetwork.download_dataset('https://cf-courses-data.s3.us.cloud-object-storage.appdomain.cloud/IBMDeveloperSkillsNetwork-DA0101EN-SkillsNetwork/labs/Data%20files/automobileEDA.csv')
# Out:
# Downloading automobileEDA.csv:   0%|          | 0/35648 [00:00<?, ?it/s]
# 'automobileEDA.csv'

# %%
# Load the data and store it in dataframe df:
df = pd.read_csv("automobileEDA.csv", header=0)

# %% [markdown]
# <h2>1. Linear Regression and Multiple Linear Regression</h2>
# <h4>Linear Regression</h4>
# <p>One example of a Data  Model that we will be using is:</p>
# <b>Simple Linear Regression</b>
#
# <br>
# <p>Simple Linear Regression is a method to help us understand the relationship between two variables:</p>
# <ul>
#     <li>The predictor/independent variable (X)</li>
#     <li>The response/dependent variable (that we want to predict)(Y)</li>
# </ul>
#
# <p>The result of Linear Regression is a <b>linear function</b> that predicts the response (dependent) variable as a function of the predictor (independent) variable.</p>

# %% [markdown]
# $$
# Y: Response \ Variable\\\\\\\\\\
# X: Predictor \ Variables
# $$

# %% [markdown]
# <b>Linear Function</b>
# $$
# Yhat = a + b  X
# $$

# %% [markdown]
# <ul>
#     <li>a refers to the <b>intercept</b> of the regression line, in other words: the value of Y when X is 0</li>
#     <li>b refers to the <b>slope</b> of the regression line, in other words: the value with which Y changes when X increases by 1 unit</li>
# </ul>

# %% [markdown]
# <h4>Let's load the modules for linear regression:</h4>

# %%
from sklearn.linear_model import LinearRegression

# %% [markdown]
# <h4>Create the linear regression object:</h4>

# %%
lm = LinearRegression()
lm
# Out:
# LinearRegression()

# %% [markdown]
# <h4>How could "highway-mpg" help us predict car price?</h4>

# %% [markdown]
# For this example, we want to look at how highway-mpg can help us predict car price.
# Using simple linear regression, we will create a linear function with "highway-mpg" as the predictor variable and the "price" as the response variable.

# %%
X = df[['highway-mpg']]
Y = df['price']

# Fit the linear model using highway-mpg:
lm.fit(X,Y)
# Out:
# LinearRegression()

# %% [markdown]
# We can output a prediction:

# %%
Yhat=lm.predict(X)
#Yhat[0:5]

# %%
Yhat
# Out:
# array([16236.50464347, 16236.50464347, 17058.23802179, 13771.3045085 ,
#        20345.17153508, 17879.97140011, 17879.97140011, 17879.97140011,
#        21988.63829172, 14593.03788682, 14593.03788682, 15414.77126514,
#        15414.77126514, 17879.97140011, 20345.17153508, 20345.17153508,
#        21988.63829172, -5128.5631929 ,  3088.77059031,  3088.77059031,
#         4732.23734696,  7197.43748192, 13771.3045085 ,  7197.43748192,
#         7197.43748192,  7197.43748192, 13771.3045085 , 13771.3045085 ,
#        18701.70477843, -5950.29657123,  7197.43748192,  3910.50396864,
#        10484.37099521, 10484.37099521, 10484.37099521, 10484.37099521,
#        11306.10437353, 11306.10437353, 11306.10437353, 11306.10437353,
#        15414.77126514, 12949.57113018, 14593.03788682, 14593.03788682,
#        22810.37167004, 22810.37167004, 24453.83842668, 12949.57113018,
#         7197.43748192,  7197.43748192,  7197.43748192,  7197.43748192,
#        19523.43815675, 19523.43815675, 19523.43815675, 19523.43815675,
#        12127.83775186, 12127.83775186, 12127.83775186, 12127.83775186,
#         3910.50396864, 12127.83775186, 16236.50464347,  6375.7041036 ,
#        17879.97140011, 17879.97140011, 17879.97140011, 17879.97140011,
#        23632.10504836, 23632.10504836, 25275.57180501, 25275.57180501,
#        18701.70477843,  4732.23734696,  7197.43748192,  7197.43748192,
#        13771.3045085 , 13771.3045085 , 12127.83775186, 18701.70477843,
#        18701.70477843, 18701.70477843, 12127.83775186, 12127.83775186,
#        13771.3045085 , 13771.3045085 ,  8019.17086025, -2663.36305794,
#         8019.17086025,  8019.17086025,  8019.17086025,  8019.17086025,
#         8019.17086025,  8019.17086025,  8019.17086025,  8019.17086025,
#        10484.37099521, 10484.37099521, 20345.17153508, 20345.17153508,
#        17879.97140011, 17879.97140011, 19523.43815675, 17879.97140011,
#        18701.70477843, 11306.10437353, 18701.70477843, 17879.97140011,
#        18701.70477843, 11306.10437353, 18701.70477843, 17879.97140011,
#        18701.70477843, 11306.10437353, 18701.70477843,  4732.23734696,
#        13771.3045085 ,  7197.43748192,  7197.43748192,  7197.43748192,
#        13771.3045085 , 18701.70477843, 16236.50464347, 17879.97140011,
#        17879.97140011, 17879.97140011, 12949.57113018, 12949.57113018,
#        15414.77126514, 15414.77126514, 15414.77126514, 15414.77126514,
#        17058.23802179, 17058.23802179,  8840.90423857, 12949.57113018,
#        12949.57113018,  8019.17086025, 11306.10437353, 12127.83775186,
#        17879.97140011, 14593.03788682, 12127.83775186, 12949.57113018,
#        14593.03788682, 19523.43815675,  6375.7041036 ,  7197.43748192,
#         7197.43748192,  8019.17086025, 12127.83775186, 12127.83775186,
#         8019.17086025,  8019.17086025,  8840.90423857,  -198.16292297,
#         -198.16292297, 10484.37099521, 10484.37099521, 10484.37099521,
#        10484.37099521, 14593.03788682, 14593.03788682, 13771.3045085 ,
#        13771.3045085 , 13771.3045085 , 13771.3045085 , 13771.3045085 ,
#        13771.3045085 , 10484.37099521, 11306.10437353, 12127.83775186,
#        12127.83775186, 12127.83775186, 18701.70477843, 18701.70477843,
#        18701.70477843, 18701.70477843,   623.57045535, 10484.37099521,
#          623.57045535, 10484.37099521, 10484.37099521,  3910.50396864,
#        12127.83775186, 14593.03788682, 14593.03788682, 18701.70477843,
#         7197.43748192, 12949.57113018, 15414.77126514, 15414.77126514,
#        15414.77126514, 15414.77126514, 20345.17153508, 20345.17153508,
#        15414.77126514, 17879.97140011, 19523.43815675, 16236.50464347,
#        17879.97140011])

# %% [markdown]
# <h4>What is the value of the intercept (a)?</h4>

# %%
lm.intercept_
# Out:
# 38423.305858157386

# %% [markdown]
# <h4>What is the value of the slope (b)?</h4>

# %%
lm.coef_
# Out:
# array([-821.73337832])

# %% [markdown]
# <h3>What is the final estimated linear model we get?</h3>
# As we saw above, we should get a final linear model with the structure:
#
# $$
# Yhat = a + b  X
# $$
# Plugging in the actual values we get:
#
# <b>Price</b> = 38423.31 - 821.73 x <b>highway-mpg</b>

# %% [markdown]
# <div class="alert alert-danger alertdanger" style="margin-top: 20px">
# <h1>Question #1 a): </h1>
#
# <b>Create a linear regression object called "lm1".</b>
#
# </div>

# %%
lm1 = LinearRegression()
lm1
# Out:
# LinearRegression()

# %% [markdown]
# <div class="alert alert-danger alertdanger" style="margin-top: 20px">
# <h1> Question #1 b): </h1>
#
# <b>Train the model using "engine-size" as the independent variable and "price" as the dependent variable?</b>
#
# </div>

# %%
X = df[['engine-size']]
Y = df[['price']]

# Fit the linear model using highway-mpg:
lm1.fit(X,Y)
# Out:
# LinearRegression()

# %% [markdown]
# <div class="alert alert-danger alertdanger" style="margin-top: 20px">
# <h1>Question #1 c):</h1>
#
# <b>Find the slope and intercept of the model.</b>
#
# </div>

# %%
# Slope 
lm1.coef_
# Out:
# array([[166.86001569]])

# %%
# Intercept
lm1.intercept_
# Out:
# array([-7963.33890628])

# %% [markdown]
# <div class="alert alert-danger alertdanger" style="margin-top: 20px">
# <h1>Question #1 d): </h1>
#
# <b>What is the equation of the predicted line? You can use x and yhat or "engine-size" or "price".</b>
#
# </div>

# %% [markdown]
# <b>Price</b> = -7963.34 + 166.86 x <b>engine-size</b>

# %%
# using X and Y  
Yhat=-7963.34 + 166.86*X

Price=-7963.34 + 166.86*df['engine-size']

# %%
print(Price)
# Out:
# 0      13728.46
# 1      13728.46
# 2      17399.38
# 3      10224.40
# 4      14729.62
#          ...
# 196    15563.92
# 197    15563.92
# 198    20903.44
# 199    16231.36
# 200    15563.92
# Name: engine-size, Length: 201, dtype: float64

# %% [markdown]
# <h2>Multiple Linear Regression</h2>
# <p>What if we want to predict car price using more than one variable?</p>
#
# <p>If we want to use more variables in our model to predict car price, we can use <b>Multiple Linear Regression</b>.
# Multiple Linear Regression is very similar to Simple Linear Regression, but this method is used to explain the relationship between one continuous response (dependent) variable and <b>two or more</b> predictor (independent) variables.
# Most of the real-world regression models involve multiple predictors. We will illustrate the structure by using four predictor variables, but these results can generalize to any integer:</p>

# %% [markdown]
# $$
# Y: Response \ Variable\\\\\\\\\\
# X\_1 :Predictor\ Variable \ 1\\\\
# X\_2: Predictor\ Variable \ 2\\\\
# X\_3: Predictor\ Variable \ 3\\\\
# X\_4: Predictor\ Variable \ 4\\\\
# $$

# %% [markdown]
# $$
# a: intercept\\\\\\\\\\
# b\_1 :coefficients \ of\ Variable \ 1\\\\
# b\_2: coefficients \ of\ Variable \ 2\\\\
# b\_3: coefficients \ of\ Variable \ 3\\\\
# b\_4: coefficients \ of\ Variable \ 4\\\\
# $$

# %% [markdown]
# The equation is given by:
# $$
# Yhat = a + b\_1 X\_1 + b\_2 X\_2 + b\_3 X\_3 + b\_4 X\_4
# $$
#
# <p>From the previous section  we know that other good predictors of price could be:</p>
# <ul>
#     <li>Horsepower</li>
#     <li>Curb-weight</li>
#     <li>Engine-size</li>
#     <li>Highway-mpg</li>
# </ul>
# Let's develop a model using these variables as the predictor variables.

# %%
Z = df[['horsepower', 'curb-weight', 'engine-size', 'highway-mpg']]

# %% [markdown]
# Fit the linear model using the four above-mentioned variables.

# %%
lm.fit(Z, df['price'])
# Out:
# LinearRegression()

# %% [markdown]
# What is the value of the intercept(a)?

# %%
lm.intercept_
# Out:
# -15806.624626329198

# %% [markdown]
# What are the values of the coefficients (b1, b2, b3, b4)?

# %%
lm.coef_
# Out:
# array([53.49574423,  4.70770099, 81.53026382, 36.05748882])

# %% [markdown]
# What is the final estimated linear model that we get?
# As we saw above, we should get a final linear function with the structure:
#
# $$
# Yhat = a + b\_1 X\_1 + b\_2 X\_2 + b\_3 X\_3 + b\_4 X\_4
# $$
#
# What is the linear function we get in this example?
#
# <b>Price</b> = -15678.742628061467 + 52.65851272 x <b>horsepower</b> + 4.69878948 x <b>curb-weight</b> + 81.95906216 x <b>engine-size</b> + 33.58258185 x <b>highway-mpg</b>

# %% [markdown]
# <div class="alert alert-danger alertdanger" style="margin-top: 20px">
# <h1> Question  #2 a): </h1>
# Create and train a Multiple Linear Regression model "lm3" where the response variable is "price", and the predictor variable is "normalized-losses" and  "highway-mpg".
# </div>

# %%
lm3 = LinearRegression()
lm3.fit(df[['normalized-losses' , 'highway-mpg']],df['price'])
# Out:
# LinearRegression()

# %% [markdown]
# <div class="alert alert-danger alertdanger" style="margin-top: 20px">
# <h1>Question  #2 b): </h1>
# <b>Find the coefficient of the model.</b>
# </div>

# %%
lm3.coef_
# Out:
# array([   1.49789586, -820.45434016])

# %% [markdown]
# <h2>2. Model Evaluation Using Visualization</h2>
# Now that we've developed some models, how do we evaluate our models and choose the best one? One way to do this is by using a visualization.
# Import the visualization package, seaborn:

# %%
# import the visualization package: seaborn
import seaborn as sns
# %matplotlib inline

# %% [markdown]
# <h3>Regression Plot</h3>
#
# ![sadas.PNG](attachment:sadas.PNG)
# <p>When it comes to simple linear regression, an excellent way to visualize the fit of our model is by using <b>regression plots</b>.</p>
#
# <p>This plot will show a combination of a scattered data points (a <b>scatterplot</b>), as well as the fitted <b>linear regression</b> line going through the data. This will give us a reasonable estimate of the relationship between the two variables, the strength of the correlation, as well as the direction (positive or negative correlation).</p>

# %% [markdown]
# Let's visualize **highway-mpg** as potential predictor variable of price:

# %%
width = 12
height = 10
plt.figure(figsize=(width, height))
sns.regplot(x="highway-mpg", y="price", data=df)
plt.ylim(0,)
# Out:
# (0.0, 48170.28467825727)

# %% [markdown]
# <p>We can see from this plot that price is negatively correlated to highway-mpg since the regression slope is negative.
#
# One thing to keep in mind when looking at a regression plot is to pay attention to how scattered the data points are around the regression line. This will give you a good indication of the variance of the data and whether a linear model would be the best fit or not. If the data is too far off from the line, this linear model might not be the best model for this data.
#
# Let's compare this plot to the regression plot of "peak-rpm".</p>

# %%
plt.figure(figsize=(width, height))
sns.regplot(x="peak-rpm", y="price", data=df)
plt.ylim(0,)
# Out:
# (0.0, 47414.1)

# %% [markdown]
# Comparing the regression plot of "peak-rpm" and "highway-mpg", we see that the points for "highway-mpg" are much closer to the generated line and, on average, decrease. The points for "peak-rpm" have more spread around the predicted line and it is much harder to determine if the points are decreasing or increasing as the "peak-rpm" increases.

# %% [markdown]
# <div class="alert alert-danger alertdanger" style="margin-top: 20px">
# <h1>Question #3:</h1>
# <b>Given the regression plots above, is "peak-rpm" or "highway-mpg" more strongly correlated with "price"? Use the method  ".corr()" to verify your answer.</b>
# </div>

# %%
df[["peak-rpm","highway-mpg","price"]].corr()
# Out:
#              peak-rpm  highway-mpg     price
# peak-rpm     1.000000    -0.058598 -0.101616
# highway-mpg -0.058598     1.000000 -0.704692
# price       -0.101616    -0.704692  1.000000

# %% [markdown]
# <h3>Residual Plot</h3>
#
#
# <p>A good way to visualize the variance of the data is to use a residual plot.</p>
#
# <p>What is a <b>residual</b>?</p>
#
# <p>The difference between the observed value (y) and the predicted value (Yhat) is called the residual (e). When we look at a regression plot, the residual is the distance from the data point to the fitted regression line.</p>
#
# <p>So what is a <b>residual plot</b>?</p>
#
# <p>A residual plot is a graph that shows the residuals on the vertical y-axis and the independent variable on the horizontal x-axis.</p>
#
# <p>What do we pay attention to when looking at a residual plot?</p>
#
# <p>We look at the spread of the residuals:</p>
#
# <p>- If the points in a residual plot are <b>randomly spread out around the x-axis</b>, then a <b>linear model is appropriate</b> for the data.
#
# Why is that? Randomly spread out residuals means that the variance is constant, and thus the linear model is a good fit for this data.</p>

# %%
width = 12
height = 10
plt.figure(figsize=(width, height))
sns.residplot(x=df['highway-mpg'],y=df['price'])
plt.show()

# %% [markdown]
# <i>What is this plot telling us?</i>
#
# <p>We can see from this residual plot that the residuals are not randomly spread around the x-axis, leading us to believe that maybe a non-linear model is more appropriate for this data.</p>

# %% [markdown]
# <h3>Multiple Linear Regression</h3>
# <p>How do we visualize a model for Multiple Linear Regression? This gets a bit more complicated because you can't visualize it with regression or residual plot.</p>
# <p>One way to look at the fit of the model is by looking at the <b>distribution plot</b>. We can look at the distribution of the fitted values that result from the model and compare it to the distribution of the actual values.</p>

# %%
Y_hat = lm.predict(Z)

# %%
plt.figure(figsize=(width, height))


ax1 = sns.distplot(df['price'], hist=False, color="r", label="Actual Value")
sns.distplot(Y_hat, hist=False, color="b", label="Fitted Values" , ax=ax1)


plt.title('Actual vs Fitted Values for Price')
plt.xlabel('Price (in dollars)')
plt.ylabel('Proportion of Cars')

plt.show()
plt.close()

# %% [markdown]
# <p>We can see that the fitted values are reasonably close to the actual values since the two distributions overlap a bit. However, there is definitely some room for improvement.</p>

# %% [markdown]
# <h2>3. Polynomial Regression and Pipelines</h2>
#
# <p><b>Polynomial regression</b> is a particular case of the general linear regression model or multiple linear regression models.</p>
# <p>We get non-linear relationships by squaring or setting higher-order terms of the predictor variables.</p>
#
# <p>There are different orders of polynomial regression:</p>
#
# <center><b>Quadratic - 2nd Order</b></center>
# $$
# Yhat = a + b_1 X +b_2 X^2
# $$
#
# <center><b>Cubic - 3rd Order</b></center>
# $$
# Yhat = a + b_1 X +b_2 X^2 +b_3 X^3\\\\\\\\\\
# $$
#
# <center><b>Higher-Order</b>:</center>
# $$
# Y = a + b_1 X +b_2 X^2 +b_3 X^3 ....\\\\
# $$
#
# <p>We saw earlier that a linear model did not provide the best fit while using "highway-mpg" as the predictor variable. Let's see if we can try fitting a polynomial model to the data instead.</p>
#
# <p>We will use the following function to plot the data:</p>

# %%
def PlotPolly(model, independent_variable, dependent_variabble, Name):
    x_new = np.linspace(15, 55, 100)
    y_new = model(x_new)

    plt.plot(independent_variable, dependent_variabble, '.', x_new, y_new, '-')
    plt.title('Polynomial Fit with Matplotlib for Price ~ Length')
    ax = plt.gca()
    ax.set_facecolor((0.898, 0.898, 0.898))
    fig = plt.gcf()
    plt.xlabel(Name)
    plt.ylabel('Price of Cars')

    plt.show()
    plt.close()

# %% [markdown]
# Let's get the variables:

# %%
x = df['highway-mpg']
y = df['price']

# %% [markdown]
# Let's fit the polynomial using the function <b>polyfit</b>, then use the function <b>poly1d</b> to display the polynomial function.

# %%
# Here we use a polynomial of the 3rd order (cubic) 
f = np.polyfit(x, y, 3)
p = np.poly1d(f)
print(p)
# Out:
#         3         2
# -1.557 x + 204.8 x - 8965 x + 1.379e+05

# %% [markdown]
# Let's plot the function:

# %%
PlotPolly(p, x, y, 'highway-mpg')

# %%
np.polyfit(x, y, 3)
# Out:
# array([-1.55663829e+00,  2.04754306e+02, -8.96543312e+03,  1.37923594e+05])

# %% [markdown]
# We can already see from plotting that this polynomial model performs better than the linear model. This is because the generated polynomial function "hits" more of the data points.

# %% [markdown]
# <div class="alert alert-danger alertdanger" style="margin-top: 20px">
# <h1>Question  #4:</h1>
# <b>Create 11 order polynomial model with the variables x and y from above.</b>
# </div>

# %%
# Here we use a polynomial of the 11rd order (cubic) 
f1 = np.polyfit(x, y, 11)
p1 = np.poly1d(f1)
print(p1)
PlotPolly(p1,x,y, 'Highway MPG')
# Out:
#             11             10             9           8         7
# -1.243e-08 x  + 4.722e-06 x  - 0.0008028 x + 0.08056 x - 5.297 x
#           6        5             4             3             2
#  + 239.5 x - 7588 x + 1.684e+05 x - 2.565e+06 x + 2.551e+07 x - 1.491e+08 x + 3.879e+08

# %% [markdown]
# <p>The analytical expression for Multivariate Polynomial function gets complicated. For example, the expression for a second-order (degree=2) polynomial with two variables is given by:</p>
#
# $$
# Yhat = a + b\_1 X\_1 +b\_2 X\_2 +b\_3 X\_1 X\_2+b\_4 X\_1^2+b\_5 X\_2^2
# $$

# %% [markdown]
# We can perform a polynomial transform on multiple features. First, we import the module:

# %%
from sklearn.preprocessing import PolynomialFeatures

# %% [markdown]
# We create a <b>PolynomialFeatures</b> object of degree 2:

# %%
pr=PolynomialFeatures(degree=2)
pr
# Out:
# PolynomialFeatures()

# %%
Z_pr=pr.fit_transform(Z)

# %% [markdown]
# In the original data, there are 201 samples and 4 features.

# %%
Z.shape
# Out:
# (201, 4)

# %% [markdown]
# After the transformation, there are 201 samples and 15 features.

# %%
Z_pr.shape
# Out:
# (201, 15)

# %% [markdown]
# <h2>Pipeline</h2>
# <p>Data Pipelines simplify the steps of processing the data. We use the module <b>Pipeline</b> to create a pipeline. We also use <b>StandardScaler</b> as a step in our pipeline.</p>

# %%
from sklearn.pipeline import Pipeline
from sklearn.preprocessing import StandardScaler

# %% [markdown]
# We create the pipeline by creating a list of tuples including the name of the model or estimator and its corresponding constructor.

# %%
Input=[('scale',StandardScaler()), ('polynomial', PolynomialFeatures(include_bias=False)), ('model',LinearRegression())]

# %% [markdown]
# We input the list as an argument to the pipeline constructor:

# %%
pipe=Pipeline(Input)
pipe
# Out:
# Pipeline(steps=[('scale', StandardScaler()),
#                 ('polynomial', PolynomialFeatures(include_bias=False)),
#                 ('model', LinearRegression())])

# %% [markdown]
# First, we convert the data type Z to type float to avoid conversion warnings that may appear as a result of StandardScaler taking float inputs.
#
# Then, we can normalize the data, perform a transform and fit the model simultaneously.

# %%
Z = Z.astype(float)
pipe.fit(Z,y)
# Out:
# Pipeline(steps=[('scale', StandardScaler()),
#                 ('polynomial', PolynomialFeatures(include_bias=False)),
#                 ('model', LinearRegression())])

# %% [markdown]
# Similarly,  we can normalize the data, perform a transform and produce a prediction  simultaneously.

# %%
ypipe=pipe.predict(Z)
ypipe[0:4]
# Out:
# array([13102.74784201, 13102.74784201, 18225.54572197, 10390.29636555])

# %% [markdown]
# <div class="alert alert-danger alertdanger" style="margin-top: 20px">
# <h1>Question #5:</h1>
# <b>Create a pipeline that standardizes the data, then produce a prediction using a linear regression model using the features Z and target y.</b>
# </div>

# %%
Input=[('scale',StandardScaler()),('model',LinearRegression())]

pipe=Pipeline(Input)

pipe.fit(Z,y)

ypipe=pipe.predict(Z)
ypipe[0:10]
# Out:
# array([13699.11161184, 13699.11161184, 19051.65470233, 10620.36193015,
#        15521.31420211, 13869.66673213, 15456.16196732, 15974.00907672,
#        17612.35917161, 10722.32509097])

# %% [markdown]
# <h2>4. Measures for In-Sample Evaluation</h2>
# <p>When evaluating our models, not only do we want to visualize the results, but we also want a quantitative measure to determine how accurate the model is.</p>
#
# <p>Two very important measures that are often used in Statistics to determine the accuracy of a model are:</p>
# <ul>
#     <li><b>R^2 / R-squared</b></li>
#     <li><b>Mean Squared Error (MSE)</b></li>
# </ul>
#
# <b>R-squared</b>
#
# <p>R squared, also known as the coefficient of determination, is a measure to indicate how close the data is to the fitted regression line.</p>
#
# <p>The value of the R-squared is the percentage of variation of the response variable (y) that is explained by a linear model.</p>
#
# <b>Mean Squared Error (MSE)</b>
#
# <p>The Mean Squared Error measures the average of the squares of errors. That is, the difference between actual value (y) and the estimated value (ŷ).</p>

# %% [markdown]
# <h3>Model 1: Simple Linear Regression</h3>
# Let's calculate the R^2:

# %%
#highway_mpg_fit
lm.fit(X, Y)
# Find the R^2
print('The R-square is: ', lm.score(X, Y))
# Out:
# The R-square is:  0.4965911884339175

# %% [markdown]
# We can say that \~49.659% of the variation of the price is explained by this simple linear model "horsepower_fit".
# Let's calculate the MSE:
# We can predict the output i.e., "yhat" using the predict method, where X is the input variable:

# %%
Yhat=lm.predict(X)
print('The output of the first four predicted value is: ', Yhat[0:4])
# Out:
# The output of the first four predicted value is:  [16236.50464347 16236.50464347 17058.23802179 13771.3045085 ]

# %% [markdown]
# Let's import the function <b>mean_squared_error</b> from the module <b>metrics</b>:

# %%
from sklearn.metrics import mean_squared_error

# %% [markdown]
# We can compare the predicted results with the actual results:

# %%
mse = mean_squared_error(df['price'], Yhat)
print('The mean square error of price and predicted value is: ', mse)
# Out:
# The mean square error of price and predicted value is:  31635042.944639895

# %% [markdown]
# <h3>Model 2: Multiple Linear Regression</h3>
# Let's calculate the R^2:

# %%
# fit the model 
lm.fit(Z, df['price'])
# Find the R^2
print('The R-square is: ', lm.score(Z, df['price']))
# Out:
# The R-square is:  0.8093562806577457

# %% [markdown]
# We can say that \~80.896 % of the variation of price is explained by this multiple linear regression "multi_fit".

# %% [markdown]
# Let's calculate the MSE.

# %% [markdown]
# We produce a prediction:

# %%
Y_predict_multifit = lm.predict(Z)

# %% [markdown]
# We compare the predicted results with the actual results:

# %%
print('The mean square error of price and predicted value using multifit is: ', \
      mean_squared_error(df['price'], Y_predict_multifit))
# Out:
# The mean square error of price and predicted value using multifit is:  11980366.87072649

# %% [markdown]
# <h3>Model 3: Polynomial Fit</h3>
# Let's calculate the R^2.

# %% [markdown]
# Let’s import the function <b>r2\_score</b> from the module <b>metrics</b> as we are using a different function.

# %%
from sklearn.metrics import r2_score

# %% [markdown]
# We apply the function to get the value of R^2:

# %%
r_squared = r2_score(y, p(x))
print('The R-square value is: ', r_squared)
# Out:
# The R-square value is:  0.674194666390652

# %% [markdown]
# We can say that \~67.419 % of the variation of price is explained by this polynomial fit.

# %% [markdown]
# <h3>MSE</h3>
# We can also calculate the MSE:

# %%
mean_squared_error(df['price'], p(x))
# Out:
# 20474146.426361218

# %% [markdown]
# <h2>5. Prediction and Decision Making</h2>
# <h3>Prediction</h3>
#
# <p>In the previous section, we trained the model using the method <b>fit</b>. Now we will use the method <b>predict</b> to produce a prediction. Lets import <b>pyplot</b> for plotting; we will also be using some functions from numpy.</p>

# %%
import matplotlib.pyplot as plt
import numpy as np

# %matplotlib inline

# %% [markdown]
# Create a new input:

# %%
new_input=np.arange(1, 100, 1).reshape(-1, 1)

# %% [markdown]
# Fit the model:

# %%
lm.fit(X, Y)
lm
# Out:
# LinearRegression()

# %%
# Produce a prediction:
yhat=lm.predict(new_input)
yhat[0:5]
# Out:
# array([37601.57247984, 36779.83910151, 35958.10572319, 35136.37234487,
#        34314.63896655])

# %%
# We can plot the data:
plt.plot(new_input, yhat)
plt.show()

# %% [markdown]
# <h3>Decision Making: Determining a Good Model Fit</h3>
# <p>Now that we have visualized the different models, and generated the R-squared and MSE values for the fits, how do we determine a good model fit?
# <ul>
#     <li><i>What is a good R-squared value?</i></li>
# </ul>
# </p>
#
# <p>When comparing models, <b>the model with the higher R-squared value is a better fit</b> for the data.
# <ul>
#     <li><i>What is a good MSE?</i></li>
# </ul>
# </p>
#
# <p>When comparing models, <b>the model with the smallest MSE value is a better fit</b> for the data.</p>
#
# <h4>Let's take a look at the values for the different models.</h4>
# <p>Simple Linear Regression: Using Highway-mpg as a Predictor Variable of Price.
# <ul>
#     <li>R-squared: 0.49659118843391759</li>
#     <li>MSE: 3.16 x10^7</li>
# </ul>
# </p>
#
# <p>Multiple Linear Regression: Using Horsepower, Curb-weight, Engine-size, and Highway-mpg as Predictor Variables of Price.
# <ul>
#     <li>R-squared: 0.80896354913783497</li>
#     <li>MSE: 1.2 x10^7</li>
# </ul>
# </p>
#
# <p>Polynomial Fit: Using Highway-mpg as a Predictor Variable of Price.
# <ul>
#     <li>R-squared: 0.6741946663906514</li>
#     <li>MSE: 2.05 x 10^7</li>
# </ul>
# </p>

# %% [markdown]
# <h3>Simple Linear Regression Model (SLR) vs Multiple Linear Regression Model (MLR)</h3>

# %% [markdown]
# <p>Usually, the more variables you have, the better your model is at predicting, but this is not always true. Sometimes you may not have enough data, you may run into numerical problems, or many of the variables may not be useful and even act as noise. As a result, you should always check the MSE and R^2.</p>
#
# <p>In order to compare the results of the MLR vs SLR models, we look at a combination of both the R-squared and MSE to make the best conclusion about the fit of the model.
# <ul>
#     <li><b>MSE</b>: The MSE of SLR is  3.16x10^7  while MLR has an MSE of 1.2 x10^7.  The MSE of MLR is much smaller.</li>
#     <li><b>R-squared</b>: In this case, we can also see that there is a big difference between the R-squared of the SLR and the R-squared of the MLR. The R-squared for the SLR (~0.497) is very small compared to the R-squared for the MLR (~0.809).</li>
# </ul>
# </p>
#
# This R-squared in combination with the MSE show that MLR seems like the better model fit in this case compared to SLR.

# %% [markdown]
# <h3>Simple Linear Model (SLR) vs. Polynomial Fit</h3>
# <ul>
#     <li><b>MSE</b>: We can see that Polynomial Fit brought down the MSE, since this MSE is smaller than the one from the SLR.</li>
#     <li><b>R-squared</b>: The R-squared for the Polynomial Fit is larger than the R-squared for the SLR, so the Polynomial Fit also brought up the R-squared quite a bit.</li>
# </ul>
# <p>Since the Polynomial Fit resulted in a lower MSE and a higher R-squared, we can conclude that this was a better fit model than the simple linear regression for predicting "price" with "highway-mpg" as a predictor variable.</p>
# <h3>Multiple Linear Regression (MLR) vs. Polynomial Fit</h3>
#
# <ul>
#     <li><b>MSE</b>: The MSE for the MLR is smaller than the MSE for the Polynomial Fit.</li>
#     <li><b>R-squared</b>: The R-squared for the MLR is also much larger than for the Polynomial Fit.</li>
# </ul>

# %% [markdown]
# <h2>Conclusion</h2>
#
# <p>Comparing these three models, we conclude that <b>the MLR model is the best model</b> to be able to predict price from our dataset. This result makes sense since we have 27 variables in total and we know that more than one of those variables are potential predictors of the final car price.</p>
